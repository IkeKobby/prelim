# %%
import pandas as pd

# %%
df = pd.read_csv('df.csv')
print(df.columns)
df.head(10)
# Out:
# Index(['ccp', 'HS_GPA', 'medianIncome', 'TERM_GPA', 'Early_alert', 'Persist',
#        'Retained', 'Scholarship Level_1.0', 'Scholarship Level_2.0',
#        'Scholarship Level_3.0', 'Scholarship Level_4.0',
#        'Scholarship Level_5.0', 'SEX_M', 'OBOR_RANK_JR', 'OBOR_RANK_NU',
#        'OBOR_RANK_SO', 'OBOR_RANK_SR', 'LIVING_CODE_OTHER'],
#       dtype='object')
#     ccp  HS_GPA  medianIncome  TERM_GPA  Early_alert  Persist  Retained  \
# 0   0.0   3.108       38677.0      3.33            0        1         1
# 1   0.0   3.490       58160.0      2.00            0        1         1
# 2  15.0   4.672       76698.0      4.00            0        1         1
# 3   0.0   3.183       64772.0      0.00            0        0         0
# 4  52.0   3.242       64831.0      2.43            1        1         1
# 5   3.0   3.505       68525.0      4.00            0        1         1
# 6  26.0   3.420       63823.0      3.00            1        1         1
# ...

# %%
list(df)
# Out:
# ['ccp',
#  'HS_GPA',
#  'medianIncome',
#  'TERM_GPA',
#  'Early_alert',
#  'Persist',
#  'Retained',
#  'Scholarship Level_1.0',
#  'Scholarship Level_2.0',
#  'Scholarship Level_3.0',
#  'Scholarship Level_4.0',
#  'Scholarship Level_5.0',
#  'SEX_M',
#  'OBOR_RANK_JR',
#  'OBOR_RANK_NU',
#  'OBOR_RANK_SO',
#  'OBOR_RANK_SR',
#  'LIVING_CODE_OTHER']

# %%
for i in list(df):
    nan_freq = "%s" % float("%.2g" % (df[i].isna().mean() * 100))
    break
nan_freq
# Out:
# '0.0'

# %%
str(df['ccp'].dtype)
# Out:
# 'float64'

# %%
"%s" % float("%.2g" % (df[i].isna().mean() * 100))
# Out:
# '0.0'

# %%
df['ccp'].isna().mean()
# Out:
# 0.0
